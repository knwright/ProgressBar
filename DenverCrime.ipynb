# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# File to Load (Remember to change these)
Denver = "Denver_crime_data.csv"
Moon = "moon_phases_2015 through 2017.csv"

# %%
Denver = pd.read_csv("Denver_crime_data.csv")
Moon = pd.read_csv("moon_phases_2015 through 2017.csv")

# %%
pd.merge(Denver, Moon, left_on = 'FIRST_OCCURRENCE_DATE' )
# Out:
#          INCIDENT_ID    OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0       2.016377e+09  2.020000e+15          5213                       0
# 1       2.018600e+10  2.020000e+16          2399                       0
# 2       2.016600e+10  2.020000e+16          2305                       0
# 3       2.018723e+08  2.020000e+14          2399                       0
# 4       2.017411e+09  2.020000e+15          2303                       0
# 5       2.018728e+08  2.020000e+14          5499                       0
# 6       2.018600e+10  2.020000e+16          2304                       0
# 7       2.018706e+08  2.020000e+14          5707                       0
# 8       2.018708e+08  2.020000e+14          5401                       0
# 9       2.018600e+10  2.020000e+16          2305                       0
# 10      2.018724e+08  2.020000e+14          3572                       0
# 11      2.018600e+10  2.020000e+16          2304                       0
# ...

# %%
Moon.head()
